# %%
import numpy as np 
import matplotlib.pyplot as plt
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))
print(colors)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='viridis')

plt.colorbar()

plt.show()
# Out:
# [17 92 82 87 31 51 74 42 59 74 26 42 88  4 89 53 39 19 58 98  4  4 93 33
#  91 78 53 53 51 78 37 87 57 42 62 34 10  7 18 17 18 98 42 18 51 21 85  9
#   4 63 43 92 92 99 61 56 13  3 26 86 32 11 73  2 58 44  4 70 97 98 23 29
#  10 11  6 57 93 60 64 43 80 79 59 98 12  0 80 53 57 97 99 69 45 55 29 15
#  79 59 49 83]
